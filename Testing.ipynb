# %%
# Before we proced we need to see how we can handle pdf file in python

# %%
pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader

# %%
pdf_file = PdfReader('Effect of friction stir processing and hybrid reinforcements on copper.pdf')

# %%
# In order to save it
content = ''
for page in pdf_file.pages:
    content = content + page.extract_text() + '\n'
